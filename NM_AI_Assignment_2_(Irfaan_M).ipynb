# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import models,layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("/content/House Price India.csv")

# %%
df
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                    2         3650      9050
# 1                       4                    2         2920      4000
# 2                       5                    2         2910      9480
# 3                       4                    2         3310     42998
# 4                       3                    2         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                    1         1556     20000
# 14616                   3                    2         1680      7000
# 14617                   2                    1         1070      6120
# 14618                   4                    1         1030      6621
# 14619                   3                    1          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                     2                   0                4
# ...

# %%
# drop dates
df = df.drop("Date",axis=1)

# %%
# drop id column
df = df.drop("id",axis=1)

# %%
df
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
# convert the no of bedrooms from float to int

df['number of bathrooms'] = df['number of bathrooms'].astype("int")

# %%
df
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                    2         3650      9050
# 1                       4                    2         2920      4000
# 2                       5                    2         2910      9480
# 3                       4                    2         3310     42998
# 4                       3                    2         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                    1         1556     20000
# 14616                   3                    2         1680      7000
# 14617                   2                    1         1070      6120
# 14618                   4                    1         1030      6621
# 14619                   3                    1          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
df['number of floors'] = df['number of floors'].astype("int")

# %%
df
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                    2         3650      9050
# 1                       4                    2         2920      4000
# 2                       5                    2         2910      9480
# 3                       4                    2         3310     42998
# 4                       3                    2         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                    1         1556     20000
# 14616                   3                    2         1680      7000
# 14617                   2                    1         1070      6120
# 14618                   4                    1         1030      6621
# 14619                   3                    1          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                     2                   0                4
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df.shape
# Out:
# (14620, 21)

# %%
X = df.drop('Price',axis=1)
Y = df.Price

# %%
X.shape
# Out:
# (14620, 20)

# %%
Y.shape
# Out:
# (14620,)

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
len(xtrain),len(ytrain)
# Out:
# (11696, 11696)

# %%
len(xtest),len(ytest)
# Out:
# (2924, 2924)

# %%
# ANN model


model = Sequential()

model.add(Dense(20,activation='relu'))
model.add(Dense(12,activation='relu'))
model.add(Dense(24,activation='relu'))
model.add(Dense(1,activation='linear'))

# %%
model.compile(optimizer='adam',loss='mse',metrics=['mse'])

# %%
model.fit(xtrain,ytrain,epochs=25,batch_size=10,validation_data=(xtest,ytest))
# Out:
# Epoch 1/25
# 1170/1170 [==============================] - 4s 3ms/step - loss: 152271028224.0000 - mse: 152271028224.0000 - val_loss: 117190647808.0000 - val_mse: 117190647808.0000
# Epoch 2/25
# 1170/1170 [==============================] - 2s 2ms/step - loss: 124993863680.0000 - mse: 124993863680.0000 - val_loss: 109928407040.0000 - val_mse: 109928407040.0000
# Epoch 3/25
# 1170/1170 [==============================] - 2s 2ms/step - loss: 107639349248.0000 - mse: 107639349248.0000 - val_loss: 77701218304.0000 - val_mse: 77701218304.0000
# Epoch 4/25
# 1170/1170 [==============================] - 3s 2ms/step - loss: 71367008256.0000 - mse: 71367008256.0000 - val_loss: 56356519936.0000 - val_mse: 56356519936.0000
# Epoch 5/25
# 1170/1170 [==============================] - 3s 2ms/step - loss: 63422132224.0000 - mse: 63422132224.0000 - val_loss: 57716240384.0000 - val_mse: 57716240384.0000
# Epoch 6/25
# ...

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 20)                420
#
#  dense_13 (Dense)            (None, 12)                252
#
#  dense_14 (Dense)            (None, 24)                312
#
#  dense_15 (Dense)            (None, 1)                 25
#
# ...
# Total params: 1,009
# Trainable params: 1,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
datas = [[3,4,3850,9150,3,1,5,6,11,3380,290,1931,1,122013,53.8645,-113.557,2890,5500,3,60]]
prediction = model.predict(datas)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# [[897715.9]]
